# %%
import pandas as pd

# %%
raw_data_df = pd.read_csv("Beach_Lab_Data.csv")

# %%
raw_data_df.head()
# Out:
#    DNA Test ID    DNA Sample Timestamp        Beach  DNA Sample 1 Reading  \
# 0          NaN                     NaN          NaN                   NaN
# 1          NaN                     NaN          NaN                   NaN
# 2          NaN                     NaN          NaN                   NaN
# 3      10601.0  06/03/2019 12:08:00 PM  63rd Street                  15.0
# 4      10600.0  06/03/2019 12:08:00 PM  South Shore                1006.0
#
#    DNA Sample 2 Reading  DNA Reading Mean  Culture Test ID  \
# 0                   NaN               NaN         107973.0
# 1                   NaN               NaN          93598.0
# 2                   NaN               NaN         108593.0
# 3                 121.0              42.6              NaN
# 4                  16.0             126.9              NaN
#
#   Culture Sample 1 Timestamp  Culture Sample 1 Reading  \
# 0     08/15/2013 12:00:00 AM                     231.0
# ...

# %%
len(raw_data_df["Beach"].unique())
# Out:
# 31

# %%
raw_data_df.columns
# Out:
# Index(['DNA Test ID', 'DNA Sample Timestamp', 'Beach', 'DNA Sample 1 Reading',
#        'DNA Sample 2 Reading', 'DNA Reading Mean', 'Culture Test ID',
#        'Culture Sample 1 Timestamp', 'Culture Sample 1 Reading',
#        'Culture Sample 2 Reading', 'Culture Reading Mean', 'Culture Note',
#        'Culture Sample Interval', 'Culture Sample 2 Timestamp', 'Latitude',
#        'Longitude', 'Location'],
#       dtype='object')

# %%
dna_data = raw_data_df[['DNA Test ID', 'DNA Sample Timestamp', 'Beach', 'DNA Sample 1 Reading',
       'DNA Sample 2 Reading', 'DNA Reading Mean', 'Latitude',
       'Longitude', 'Location']]
dna_data.head()
# Out:
#    DNA Test ID    DNA Sample Timestamp        Beach  DNA Sample 1 Reading  \
# 0          NaN                     NaN          NaN                   NaN
# 1          NaN                     NaN          NaN                   NaN
# 2          NaN                     NaN          NaN                   NaN
# 3      10601.0  06/03/2019 12:08:00 PM  63rd Street                  15.0
# 4      10600.0  06/03/2019 12:08:00 PM  South Shore                1006.0
#
#    DNA Sample 2 Reading  DNA Reading Mean  Latitude  Longitude  \
# 0                   NaN               NaN       NaN        NaN
# 1                   NaN               NaN       NaN        NaN
# 2                   NaN               NaN       NaN        NaN
# 3                 121.0              42.6   41.7827   -87.5748
# 4                  16.0             126.9   41.7689   -87.5636
#
#               Location
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3  (41.7827, -87.5748)
# ...

# %%
culture_data = raw_data_df[['Beach', 'Culture Sample 1 Reading',
       'Culture Sample 2 Reading', 'Culture Reading Mean', 'Latitude',
       'Longitude', 'Location']]

# %%
culture_data
# Out:
#              Beach  Culture Sample 1 Reading  Culture Sample 2 Reading  \
# 0              NaN                     231.0                     248.0
# 1              NaN                      12.0                       4.0
# 2              NaN                       2.0                       2.0
# 3      63rd Street                       NaN                       NaN
# 4      South Shore                       NaN                       NaN
# ...            ...                       ...                       ...
# 24280        Leone                      25.0                      18.0
# 24281       Howard                      30.0                      36.0
# 24282  South Shore                       NaN                       NaN
# 24283       Howard                      10.8                       8.6
# 24284      Rainbow                      25.0                      12.0
#
#        Culture Reading Mean  Latitude  Longitude             Location
# ...

# %%
raw_cell_culture_data = culture_data.dropna()

# %%
raw_dna_data = dna_data.dropna()

# %%
raw_dna_data
# Out:
#        DNA Test ID    DNA Sample Timestamp         Beach  \
# 3          10601.0  06/03/2019 12:08:00 PM   63rd Street
# 4          10600.0  06/03/2019 12:08:00 PM   South Shore
# 5          10582.0  06/03/2019 12:10:00 PM  North Avenue
# 6          10646.0  06/03/2019 12:12:00 PM        Howard
# 7          10599.0  06/03/2019 12:08:00 PM       Rainbow
# ...            ...                     ...           ...
# 24273       3116.0  06/21/2017 12:00:00 AM      Humboldt
# 24274       7874.0  07/11/2018 12:00:00 AM        Howard
# 24277       2047.0  08/24/2016 01:13:00 PM  North Avenue
# 24279       2980.0  06/18/2017 12:00:00 AM   57th Street
# 24282       3105.0  06/20/2017 12:00:00 AM   South Shore
#
#        DNA Sample 1 Reading  DNA Sample 2 Reading  DNA Reading Mean  Latitude  \
# 3                      15.0                 121.0              42.6  41.78270
# 4                    1006.0                  16.0             126.9  41.76890
# ...

# %%
raw_dna_data.to_csv("cleaned_data/Raw_DNA_Data.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-33-cc58946b9105> in <module>
# ----> 1 raw_dna_data.to_csv("cleaned_data/Raw_DNA_Data.csv")
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal)
#    3202             decimal=decimal,
#    3203         )
# -> 3204         formatter.save()
#    3205
#    3206         if path_or_buf is None:
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/io/formats/csvs.py in save(self)
#     182             close = False
#     183         else:
# --> 184             f, handles = get_handle(
#     185                 self.path_or_buf,
#     186                 self.mode,
#
# ...
